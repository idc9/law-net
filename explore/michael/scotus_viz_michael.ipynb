# %%
import sys

sys.path.append('../../code/')
import os
import time

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import networkx as nx

from load_data import case_info, load_citation_network

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

data_dir = '../../data/'
network = 'scotus'
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
G = load_citation_network(data_dir, 'scotus')
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-5-b5b9e501db5a> in <module>()
# ----> 1 G = load_citation_network(data_dir, 'scotus')
#
# C:\Users\Michael\Documents\GitHub\law-net\code\load_data.pyc in load_citation_network(data_dir, network)
#      42
#      43         case_metadata = pd.read_csv(net_dir + 'case_metadata.csv',
# ---> 44                                      index_col='id')
#      45
#      46         edgelist = pd.read_csv(net_dir + 'edgelist.csv')
#
# ...
