# %% [markdown]
# This notebook shows you how to load the SCOTUS citation network. Once you change the code in the next block to match your computer you should be good to go (yes this is a little jenky)

# %%
# path to the top directory
top_directory = '/Users/iaincarmichael/Dropbox/Research/law/law-net/'

# %%
import sys
import numpy as np
import matplotlib.pyplot as plt
import igraph as ig

# our code
sys.path.append(top_directory + 'code') 
from load_data import load_and_clean_graph, case_info

# where to find the data
data_dir = top_directory + 'data/'

# which court to load
court_name = 'scotus'

# jupyter notebook settings
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # load the scotus network

# %%
# load the network as an igraph object
G = load_and_clean_graph(data_dir, court_name)

# %%
# everyone loves pagerank!
G.pagerank()
# Out:
# [1.1150736683707751e-05,
#  1.3548513364925309e-05,
#  1.5186126737260779e-05,
#  2.6725360780535234e-05,
#  1.876777679961106e-05,
#  2.8509308610805708e-05,
#  3.5833830555859176e-05,
#  5.3203899486434025e-05,
#  1.0139854122065664e-05,
#  4.893728846879041e-05,
#  0.00010379400081232842,
#  0.00010107721528839153,
#  1.0665667314789666e-05,
#  1.785683499610801e-05,
#  1.527372704543334e-05,
#  3.6862996785003015e-05,
#  1.4115859283489225e-05,
#  1.0139854122065664e-05,
#  0.00019763813713321863,
#  1.0139854122065664e-05,
#  6.731582017250638e-05,
#  1.6109101007350183e-05,
#  5.528326451692766e-05,
#  0.0001519579307640783,
#  1.7787120929111767e-05,
#  4.625128152829568e-05,
#  1.62477501905176e-05,
#  1.0877681041732951e-05,
#  3.092193852863559e-05,
#  1.575551101937805e-05,
#  2.1824063539995795e-05,
#  1.0961653078454167e-05,
#  1.9876279178131944e-05,
#  1.4843016260416975e-05,
#  4.991566061916074e-05,
#  1.8844321513135334e-05,
#  1.474754079426324e-05,
# ...
